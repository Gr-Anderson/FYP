# %% [markdown]
# # Sendex - Template Matching

# %%
# https://www.youtube.com/watch?v=2CZltXv-Gpk

import cv2
import numpy as np

def read_in_ecg():
    img = cv2.imread("captured.png", 0)
    return img

def aquire_template(img):
    template = img[7:19,17:29]
    return template

# flipVertical = cv2.flip(img, 0)



def match_template():
    img = read_in_ecg()
    template = aquire_template(img)

    w, h = template.shape[::-1]
    res = cv2.matchTemplate(img,template,cv2.TM_CCOEFF_NORMED)
    threshold = 0.9
    loc = np.where( res >= threshold)
    for pt in zip(*loc[::-1]):
        cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
    cv2.imshow('Detected',img)
    cv2.waitKey(0) & 0xFF
    cv2.destroyAllWindows()

# print(img.shape)
# print(x_start, x_end, y_start, y_end)
# print("Feature: ", feature_to_match.shape, "\n")
    
match_template()

# %%
# image_test
import cv2
import numpy as np

img = cv2.imread('captured.png', 0)

template = img[7:19,17:29]
w, h = template.shape[::-1]

res = cv2.matchTemplate(img,template,cv2.TM_CCOEFF_NORMED)
threshold = 0.9
loc = np.where( res >= threshold)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
# if np.amax(res) > threshold:
#     flag = True
# if (len(loc) != 0):
#     print ("YES MODDAFUCKERS")
# else:
#     print ("DAMN FOOL")
# print (loc)

# for pt in zip(*loc[::-1]):
#      cv2.rectangle(img_ecg, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)

cv2.imshow('Detected',img)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cece3117e9ab> in <module>
#      24 #      cv2.rectangle(img_ecg, pt, (pt[0] + w, pt[1] + h), (0,255,255), 2)
#      25
# ---> 26 cv2.imshow('Detected',img_ecg)
#      27 cv2.waitKey(0) & 0xFF
#      28 cv2.destroyAllWindows()
#
# NameError: name 'img_ecg' is not defined

# %%
# https://www.youtube.com/watch?v=sghglbXyjHc&t=406s
import cv2
img = cv2.imread("image_test.png")




# crop_img = img[y:y+h, x:x+w]
crop_img = img[70:500,160:570]
cv2.imshow("cropped", crop_img)



# cv2.imshow('Detected',img)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()

# %%
# Python program to explain cv2.rectangle() method  
   
# importing cv2  
import cv2  
   
# path  
path = r'image_test.png'
   
# Reading an image in default mode 
image = cv2.imread(path) 
   
# Window name in which image is displayed 
window_name = 'Image'
  
# Start coordinate, here (5, 5) 
# represents the top left corner of rectangle 
start_point = (5, 5) 
  
# Ending coordinate, here (220, 220) 
# represents the bottom right corner of rectangle 
end_point = (220, 220) 
  
# Blue color in BGR 
color = (255, 0, 0) 
  
# Line thickness of 2 px 
thickness = 2
  
# Using cv2.rectangle() method 
# Draw a rectangle with blue line borders of thickness of 2 px 
image = cv2.rectangle(image, start_point, end_point, color, thickness) 
  
# Displaying the image  
cv2.imshow(window_name, image)
cv2.waitKey(0) & 0xFF
cv2.destroyAllWindows()
